# %%
import pandas as pd

df = pd.read_csv('../../data hackathon EFREI/hr_dataset_fr.csv', encoding='ISO-8859-1', delimiter=';')

# %%
df
# Out:
#        id                        nom                                  email  \
# 0    E001                 John Smith                 john.smith@company.com
# 1    E002               Sara Johnson               sara.johnson@company.com
# 2    E003           Miguel Rodriguez           miguel.rodriguez@company.com
# 3    E004                  Emma Chen                  emma.chen@company.com
# 4    E005               David Miller               david.miller@company.com
# ..    ...                        ...                                    ...
# 112  E113         Ãtienne MarÃ©chal           étienne.maréchal@company.com
# 113  E114  Marianne-Joséphine Dijoux  marianne-joséphine.dijoux@company.com
# 114  E115         Alain Faivre-Payet         alain.faivre-payet@company.com
# 115  E116        Thomas-Noël Le Roux           thomas-noël.roux@company.com
# 116  E117             Claire Verdier             claire.verdier@company.com
#
# ...
